# %% [markdown]
# # T.P. de chimie n° 1
#
# # Conductimétrie : détermination d’une constante d’équilibre

# %% [markdown]
# **Objectif** : mettre en œuvre une démarche expérimentale pour déterminer une constante d’équilibre en solution aqueuse.
#
# **Autres capacités mobilisées** :
# * utiliser une appareil de mesure de conductance en s’aidant d’une notice ;
# * sélectionner et utiliser le matériel adapté à la précision requise ;
# * préparer une solution aqueuse de concentration donnée à partir d’une solution de concentration molaire donnée.
#
# **Préparation :** dans le paragraphe III, répondre aux questions 2 à 8.

# %% [markdown]
# ## I – Principe de la conductimétrie

# %% [markdown]
# Un conductimètre mesure la conductance $G$ de la portion d’électrolyte comprise entre deux plaques de platine (la cellule conductimétrique) de surface $S$, distantes de $\ell$, plongeant dans la solution :
# $$G=\frac1R=\frac{\gamma S}{\ell}\ .$$
# Cette formule, établie au chap. 28, est utilisée pour une cellule cylindrique, mais elle n’est qu’approchée, en raison des effets de bords (les lignes de courant ne sont pas toutes parallèles entre elles et
# certaines « sortent » de la cellule, mais la proportionnalité de $G$ à
# $\gamma$ est souvent suffisante et
# $$G = k\gamma\ ,$$
# où $k$ désigne la constante de cellule.

# %% [markdown]
# Afin d’accéder à $\gamma$, la cellule de conductimétrie doit être étalonnée : cela consiste à mesurer la conductance $G$ d’une solution étalon de conductivité $\gamma$ connue. L’appareil ajuste alors la valeur de $k$ et affiche $G/k = \gamma$.

# %% [markdown]
# Dans la solution, la conductivité est assurée par les ions notés A$_i^{z_i+}$ ou A$_i^{z_i-}$ (par exemple Fe$^{2+}_{(aq)}$, Na$^+_{(aq)}$, SO$_{4(aq)}^{2-}$) ; $z_i$ est donc le nombre algébrique de charges $e$. La formule de Kohlraush (chap. 28) s’écrit alors :
# $$\gamma= \sum_i C_i \lambda_i\ ,$$
# avec $C_i$ en  **mol.m$^{-3}$**. La grandeur positive $\lambda_i$ est appelée *conductivité ionique molaire*. En réalité $λ_i$ dépend de la concentration totale $C$ en ions dans la solution, selon la loi
# empirique
# $$\lambda_i= \lambda_i^\circ-\alpha \sqrt C\ .$$

# %% [markdown]
# Pour des solutions suffisamment diluées ($C < 10^{-3}$ mol.L$^{-1}$),
# on admet que $\lambda_i \simeq λ_i^\circ$, où $\lambda_i^\circ$ désigne
# la *conductivité ionique molaire limite*. Les conductivités ioniques molaires limites sont regroupées dans des tables ramenées à une mole
# de charge : on tabule ainsi
# $$\frac{1}{|z_i|}\lambda_i^\circ(\mbox{A}_i^{z_{i}+})=\lambda_i^\circ\left(\frac{1}{|z_i|}\mbox{A}_i^{z_{i}+}\right)\ .$$

# %% [markdown]
# Pour les valeurs données dans le tableau ci-dessous,

# %% [markdown]
# | $\mbox{ion}$ | $\mbox{H}^+_{(aq)}$  | $\mbox{Na}^+_{(aq)}$  | $\frac13\mbox{Fe}^{3+}_{(aq)}$  | $\mbox{OH}^{-}_{(aq)}$ | $\mbox{CH}_3\mbox{CO}_{2(aq)}^-$ | $\frac12\mbox{SO}^{2-}_{4(aq)}$ |
# | :---: | :-----: | :-----: | :-----: | :-----: | :-----: | :-----: |
# | $\lambda^\circ\mbox{ (en mS.m$^2$.mol$^{-1}$)}$ | $35,\!0$ | $5,\!0$ | $6,\!8$ | $19,\!9$ | $4,\!1$ | $8,\!0$ |

# %% [markdown]
# On utilisera donc la relation
# $$\gamma = \sum_i|z_i|c_i\lambda^\circ_i\left(\frac{1}{|z_i|}\mbox{A}_i^{z_{i}+}\right)\ .$$

# %% [markdown]
# ## II – Protocole
#
# **A chaque changement de solution, la cellule conductimétrique sera systématiquement rincée à l’eau distillée, puis séchée au papier filtre, mais sans toucher la surface des électrodes.**

# %% [markdown]
# 1. A partir de la solution d’acide éthanoïque (nom courant : acide acétique) à $C =10^{-1}$ mol/L, effectuer trois dilutions pour obtenir des volumes de 100 mL de solutions à 5.10$^{-2}$ mol/L, 2.10$^{-2}$ mol/L  et 10$^{-2}$ mol/L.
#
# 2. Étalonnage du conductimètre :
#
# > (a) lire le principe de l’étalonnage sur la notice ;
#
# > (b) immerger la cellule de conductimétrie dans une solution de KCl à 10$^{-1}$ mol/L et éliminer les éventuelles bulles qui pourrait subsister entre les électrodes ;
#
# > (c) réaliser l’étalonnage de la cellule ;
#
# > (d) retirer la solution d’étalonnage et immerger la cellule de conductimétrie (toujours sans bulles) dans la solution d’acide éthanoïque à C = 10$^{-2}$ mol/L.
#
# 3. Mesurer la conductivité de chacune de ces quatre solutions, de concentration notée $C$, en procédant de la solution la moins concentrée à la plus concentrée. Attention, les mesures sont affichées en $\mu$S/cm ou en mS/cm
#
# 4. A partir de la solution d’acide éthanoïque à C = 10$^{-1}$ mol/L, effectuer deux dilutions pour obtenir deux volumes de 100 mL de solution à 10$^{-3}$ mol/L et 10$^{-4}$ mol/L.
#
# 5. Mesurer la conductivité de chacune de ces deux solutions.

# %% [markdown]
# ##  III – Travail demandé

# %% [markdown]
# **Premières manipulations**
# > 1. Mettre les étapes 1 à 3 du protocole en application.

# %% [markdown]
# **Partie théorique**
#
# On étudie la réaction de dissociation dans l’eau de l’acide éthanoïque
# (présent dans le vinaigre), noté AH. La solution étudiée est de concentration $C$. On introduit la concentration standard $C^\circ= 1 \mbox{mol/L} = 10^3 \mbox{mol/m}^{-3}$ que l’on fera figurer
# dans l’expression de la constante.
#
# 2. Écrire la réaction de dissociation avec un tableau d’avancement faisant apparaître le taux de dissociation $\alpha$.

# %% [markdown]
# Réponse : la réaction est
# $$\mbox{HA}_{(aq)}=\mbox{H}^+_{(aq)}+\mbox{A}^-_{(aq)}\ .$$
# On notant $V$ le volume de solution, le tableau d'avancement est le suivant :
# > | $\mbox{Espèces}$ |$\mbox{HA}^+_{(aq)}$ | $\mbox{H}^+_{(aq)}$ | $\mbox{A}^-_{(aq)}$ |
# > |:---:|:---:|:---:|:---:|
# > | $t=0$ | $CV$ | $0$ | $0$ |
# > | $t_f$ | $CV-\xi_f$ | $\xi_f$ | $\xi_f$ |
# > | $t_f$ | $CV(1-\alpha)$ | $CV\alpha$ | $CV\alpha$ |
#
# car la taux de dissociation s'exprime
# $$\alpha=\frac{\xi_f}{CV}\ .$$

# %% [markdown]
# 3. Relier la constante d’équilibre $K_a$ à $C$, $C^\circ$ et $\alpha$.

# %% [markdown]
# Réponse : on trouve
# $$K_a=Q_r^{eq}=\frac{{C^\circ}[\mbox{A}^-_{(aq)}][\mbox{H}^+_{(aq)}]}{[\mbox{HA}_{(aq)}]{C^\circ}^2}=\frac{C^2\alpha^2}{C(1-\alpha)C^\circ}=\frac{C}{C^\circ}\frac{\alpha^2}{1-\alpha}\ .$$

# %% [markdown]
# 4. On néglige la présence des ions OH$^-_{aq}$ venant de l’autoprotolyse de l’eau. Écrire une condition sur le pH pour pouvoir négliger la présence des ions OH$^{-}_{aq}$.

# %% [markdown]
# Réponse : pour pouvoir négliger la présence des ions OH$^-_{(aq)}$,
# $$[\mbox{H}^{+}_{(aq)}]\gg [\mbox{OH}^{-}_{(aq)}] \quad\Leftrightarrow\quad [\mbox{H}^{+}_{(aq)}]\gg \frac{K_e{C^\circ}^2}{[\mbox{H}^{+}_{(aq)}]}\quad\Leftrightarrow\quad [\mbox{H}^{+}_{(aq)}]^2\gg K_e {C^\circ}^2\ , $$
# ce qui se traduit par
# $$a_{H^+_{aq}}^2=\frac{[\mbox{H}^{+}_{(aq)}]^2}{{C^\circ}^2} >100K_e\ , $$
# soit
# $$2\mbox{ pH}<-\log(100K_e)=-2+\mbox{p}K_e\ ,$$
# d'où
# $$\mbox{pH}<\frac{1}{2}\mbox{p}K_e-1=6\ . $$

# %% [markdown]
# 5. Exprimer la conductivité de la solution en fonction des concentrations des ions présents, puis en fonction de $C^\circ$, $C$, $\alpha$ et $\lambda^\circ= \lambda^\circ_{A^-} + \lambda^\circ_{H^+}$.

# %% [markdown]
# Réponse : on trouve :
# $$\gamma=[\mbox{H}^{+}_{(aq)}]\lambda^\circ_{H^+_{(aq)}}+[\mbox{A}^{-}_{(aq)}]\lambda^\circ_{A^-_{(aq)}}=C\alpha(\lambda^\circ_{H^+_{(aq)}}+\lambda^\circ_{A^-_{(aq)}})=C\alpha\lambda^\circ\ . $$

# %% [markdown]
# On suppose l’acide faiblement dissocié : à l’équilibre $$[\mbox{A}H_{aq}]\simeq C \Leftrightarrow \alpha \ll 1\ ,$$
# traduite par $\alpha <1/10$.
#
# On pose $\lambda = \gamma/C$ et p$C=-\log(C/C^\circ)$.
#
# 6. Quelle contrainte vérifient $\lambda$ et $\lambda^\circ$ si l’acide est faiblement dissocié ?

# %% [markdown]
# Réponse : on trouve
# $$\lambda=\frac{\gamma}{C}=\alpha\lambda_\circ\ .$$
# L'acide est peu dissocié si $\lambda=\alpha\lambda_\circ\ll\lambda_\circ$, donc si
# $$\lambda<\frac{\lambda_\circ}{10}\ . $$

# %% [markdown]
# 7. Montrer que $$K_a = \frac{C}{C^0}\left(\frac{\lambda}{\lambda^0}\right)^2\ .$$ En déduire l’expression de p$C$ en fonction de p$K_a$ et $2\log(\lambda/\lambda^\circ)$.

# %% [markdown]
# Réponse : avec $\lambda=\alpha\lambda_\circ$, donc
# $$K_a=\frac{C\alpha^2}{C^\circ(1-\alpha)}\simeq \frac{C}{C^\circ}\alpha^2=\frac{C}{C^\circ}\left(\frac{\lambda}{\lambda^\circ}\right)^2\ , $$
# donc
# $$\mbox{p}K_a=\mbox{p}C-2\log\left(\frac{\lambda}{\lambda^0}\right)\ . $$

# %% [markdown]
# 8. Par ailleurs, exprimer le pH en fonction du p$K_a$ et de p$C$.

# %% [markdown]
# Réponse : on trouve
# $$K_a\simeq \alpha^2\frac{C}{C^\circ}=\left(\frac{C\alpha}{C^\circ}\right)^2\frac{C^\circ}{C}=\left(\frac{[\mbox{H}^+_{aq}]}{C^\circ}\right)^2\frac{C^\circ}{C}$$
# donc
# $$\mbox{p}K_a=2\mbox{pH}-\mbox{p}C\ .$$

# %% [markdown]
# **Exploitation**
#
# 9. Compléter la cellule n°2 du code ci-dessous (faire attention aux unités en commentaires), puis exécuter les cellules 1 à 3 pour représenter p$C$ en fonction de $2\log(\lambda/\lambda^\circ)$.

# %%
#%% Cellule n°1 : importations

import numpy as np
from matplotlib import pyplot as plt

# %%
#%% Cellule n°2 : mesures

tab_C=np.array([0.1,0.05,0.03,0.01])                     # Tableau des valeurs de C en mol/L
tab_Cp=1000 * tab_C                                      # Tableau des valeurs de C en mol/m**3
C0=1000                                                  # Concentration standard en mol/m**3
tab_conduct=np.array([59,41.3,27.2,19.27])               # Tableau des valeurs des conductivités mesurées en mS/m
tab_lambda=tab_conduct/tab_Cp                            # Tableau des valeurs de lambda en mS/m**2/mol 
lambda0=39.1                                             # lambda0 en mS/m**2/mol 

tab_absc=2*np.log10(tab_lambda/lambda0)                  # Valeurs en abscisses
tab_ord=-np.log10(tab_Cp/C0)                             # Valeurs en ordonnées

# %%
#%% Cellule n°3 : représentation graphique 

plt.figure()
plt.ylabel(r'pC')
plt.xlabel(r'$2\log(\lambda/\lambda_0)$')
plt.plot(tab_absc, tab_ord,'o',color = 'k')
plt.show()

# %% [markdown]
# 10. Compléter et exécuter la cellule n° 4 pour tracer la droite de regression et afficher la valeur du p$Ka$. Commenter.

# %%
#%% Cellule n°4 : régression linéaire

def regression(tab_X,tab_Y):                    # Fonction à compléter
    b=np.sum(tab_Y-tab_X)/len(tab_X)
    return b

pKa=regression(tab_absc,tab_ord)
print('pKa= ',pKa)
plt.plot(tab_absc, tab_ord,'o',color = 'k')
plt.plot(tab_absc, tab_absc+pKa,color = 'r') 
plt.show()
# Out:
# pKa=  4.675249988561555

# %% [markdown]
# 11. Réaliser des représentations graphiques afin de vérifier que les hypothèses sont respectées.

# %%
#%% Cellule n°5 : représentation de alpha

plt.figure()
plt.ylabel(r'$\alpha$')
plt.xlabel(r'pC')
plt.plot(tab_ord, tab_lambda/lambda0,'o',color = 'b')
plt.show()

# %%
#%% Cellule n°6 : représentation de pH

plt.figure()
plt.ylabel(r'pH')
plt.xlabel(r'pC')
plt.plot(tab_ord, (tab_ord+pKa)/2,'o',color = 'g')
plt.show()

# %% [markdown]
# **Manipulations supplémentaires** (si le temps le permet)
#
# 12. Mettre les étapes 4 et 5 du protocole en application.
#
# 13. Compléter le graphe par les deux autres mesures. Commenter.
