# %% [markdown]
# # TP 6 - Multiplexage fréquentiel
#
# Ce TP, étalé sur deux séances, est consacré au partage de canal de transmission par multiplexage fréquentiel.
#
# **Objectif**
# Il permet de :
# * cabler un montage comportant un ALI ;
# * tracer un diagramme de Bode ;
# * étudier l’effet d’un filtre sur un signal d’entrée.

# %% [markdown]
# ## I - Principe de l’ADSL : multiplexage fréquentiel
#
# Source : http://igm.univ-mlv.fr/~dr/XPOSE2006/Julien_Walspurger/principe/principe.html
#
# Le but de l’ADSL (Asymmetric Digital Subscriber Line) est de permettre le transport des données concernant la voix (c’est-à-dire le téléphone, dit RTC) et celles en provenance et à destination d'Internet sur le même support physique : la paire de cuivre. Pour ce faire, l’ADSL utilise le multiplexage fréquentiel, c’est-à-dire que la bande passante du
# support est divisée en trois largeurs de fréquences différentes :
# * le premier canal contient les données voix ;
# * le second les données à destination d’Internet ;
# * le troisième les données en provenance d’Internet.
#
# L’ADSL étant une technologie asynchrone, le débit « abonné vers opérateur » n’est pas le même que le débit « opérateur vers abonné ». En l’occurrence en ADSL, le débit ascendant est plus petit que le débit descendant. Ce choix est dû au fait que sur Internet, l’abonné reçoit plus de données qu’il n’en émet.
#
# **Le multiplexage**
#
# Le multiplexage le plus couramment utilisé pour l’ADSL est le FDM
# (Frequency Division Multiplexing) : un multiplexage fréquentiel. Le principe consiste à séparer les plages de fréquences d’une bande passante pour ainsi transiter un type de données par plages. Dans le cas de l’ADSL, la bande passante du support de transmission
# utilisée est de 1,1 MHz. Il faut alors la diviser en 3 parties :
# * 0 à 4 kHz : la bande de fréquence consacrée aux données voix ;
# * 5 à 20 kHz : une bande de fréquence laissée vide pour séparer les données téléphoniques et les données Internet ;
# * 20 à 140 kHz : la bande de fréquence consacrée aux données montantes ;
# * 150 à 1100 kHz : la bande de fréquence consacrée aux données descendantes.

# %% [markdown]
# ![Multiplex1.jpeg](attachment:Multiplex1.jpeg)
#
# <p style="text-align: center;">Figure n°1 : les différentes bandes de fréquence de l'ADSL</p>

# %% [markdown]
# La modulation utilisée pour l’ADSL est DMT (Discrete Multi Tone).
# Le principe est de découper la bande passante en 256 canaux de 4,3 kHz.
# * Le premier canal est réservé aux données voix
# * 17 canaux sont réservés aux données numériques montantes
# * 225 canaux sont réservés aux données numériques descendantes.
# Ces chiffres montrent clairement pourquoi l’ADSL propose des débits asymétriques et que le débit descendant est plus important que celui montant.

# %% [markdown]
# ![Multiplex2.jpeg](attachment:Multiplex2.jpeg)
#
# <p style="text-align: center;">Figure n°2 : les différents canaux</p>

# %% [markdown]
# ## II - Filtre de Rausch
# On cherche alors à étudier comment récupérer un canal au sein d’un signal multiplexé.
#
# ### B : Etude du filtre
# **Préparation**
# 1. Quel type de filtre est nécessaire a priori pour récupérer un unique canal ? Comment choisir sa fréquence caractéristique ? et son facteur de qualité ?

# %% [markdown]
# Réponse :

# %% [markdown]
# On va s’intéresser au filtre de Rausch suivant :

# %% [markdown]
# ![Rausch.jpeg](attachment:Rausch.jpeg)
#
# <p style="text-align: center;">Figure n°3 : filtre de Rausch</p>

# %% [markdown]
# Il est constitué de résistances, de condensateurs et d’un composant appelé ALI, ici en fonctionnement linéaire et dont la description est donnée en Annexe.
#
# 2. Par une analyse basses et hautes fréquences du montage, déterminer le type de filtre réalisé par ce circuit (on lira l’annexe et on appliquera dans chaque cas une loi des mailles adaptée).

# %% [markdown]
# Réponse

# %% [markdown]
# On se place désormais dans le cas où $C_1 = C_2 = C$ et $R_1=R_2=R$.
# La valeur de $R_3$ est en revanche différente de celle de $R$. Dans cette situation, la fonction de transfert de ce filtre s’écrit :
# $$\underline{H}(\jmath\omega)=-\frac{R_3}{2R}\frac{RC\jmath \omega}{1+\jmath RC\omega +\frac{R_3R}{2}C^2\left(\jmath\omega\right)^2} \ .$$
# On choisit $R = 1$ k$\Omega$, $R_3 = 100$ k$\Omega$ et $C = 10$ nF.
#
# 3. Quel type de filtre obtient-on ainsi ? Donner l’expression de sa fréquence de résonance, de son facteur de qualité et de son gain à la résonance. Faire les applications numériques.

# %% [markdown]
# Réponse :

# %% [markdown]
# 4. Quel est l’intérêt d’un tel filtre par rapport à un filtre RLC usuel ?

# %% [markdown]
# Réponse :

# %% [markdown]
# 5. Établir que :
# $$\frac{u(f_0)}{f_0}=\sqrt{\frac14  \left(\frac{u(R)}{R}\right)^2+\frac14  \left(\frac{u(R_3)}{R_2}\right)^2+\left(\frac{u(C)}{C}\right)^2}\ .$$
# Sachant que la tolérance sur les valeurs de chaque composant est de $1\%$, quelle est l’incertitude que nous avons sur la fréquence de résonance ?

# %% [markdown]
# Réponse

# %% [markdown]
# 6. Tracer, en justifiant, les diagrammes de Bode asymptotique et réel de ce filtre.
#
# 7. Sous quelles conditions ce filtre peut-il se comporter comme un dérivateur pur ? un intégrateur pur ?

# %% [markdown]
# Réponse :

# %% [markdown]
# Nous allons câbler ce montage. L’ALI est un composant actif, qui doit donc être alimenté par une alimentation symétrique $+15$ V/$-15$ V.
# On alimente toujours un composant actif avant de lui soumettre son signal d’entrée. Mettre un signal d’entrée sur un composant actif non alimenté peut le détruire.
#
# **Manipulation**
#
# 1. Câbler le montage et vérifier rapidement le type de filtrage effectué ainsi que la fréquence de résonance $f_0$
#  et le gain dans la bande passante $H_0$.
#
# 2. Justifier que, dans le cas présent, le mode XY est particulièrement adapté pour détecter avec précision la fréquence de résonance.

# %% [markdown]
# Réponse

# %% [markdown]
# 3. Qu’observe-t-on à la sortie du filtre quand on se place près de la résonance et que l’amplitude du signal d’entrée est un peu trop grande ?

# %% [markdown]
# Réponse :

# %% [markdown]
# 4. Tracer le diagramme de Bode en gain et en phase de ce filtre.
#    Pour cela, à chaque valeur de la fréquence,  utiliser les fonctions de mesures de l'oscilloscope pour accéder à        $V_e$, $V_S$ et $f_0$.
#    Utiliser les curseurs pour mesurer le décalage temporel algébrique $\tau$ de $u_s$ par rapport à $u_e$.
#    Calculer ensuite l'avance de phase avec $$\varphi=-2\pi f_0\tau\ .$$

# %%
import matplotlib.pyplot as plt
import numpy as np

tab_f=np.array([,])    # Valeurs des fréquences à saisir en kHz
tab_Ve=np.array([,])               # Valeurs des amplitudes de la tension d'entrée à saisir en V
tab_Vs=np.array([,])           # Valeurs des amplitudes de la tension d'entrée à saisir en V
tab_retard=np.array([,])           # Valeurs des retards à saisir en ms

tab_x=        # Tableau des abscisses à calculer
tab_y=          # Tableau des ordonnées à calculer
plt.figure()
plt.ylabel(r'$G_{dB}$')
plt.xlabel(r'$\log(f)$')
plt.plot(tab_x,tab_y,'o')                    
plt.show()          


plt.figure()  
tab_x=                   # Tableau des abscisses à calculer
tab_y=             # Tableau des ordonnées à calculer                               
plt.ylabel(r'$\varphi(rad)$')
plt.xlabel(r'$\log(f)$')
plt.plot(tab_x,tab_y,'o')                 
plt.show()

# %% [markdown]
# ### B : Effet du filtre sur un signal d’entrée créneau particulier
#
# Dans un premier temps, on choisit un signal d’entrée créneau, de fréquence $f = 446$ Hz.
#
# 5. Mettre ce signal en entrée et montrer qu’on obtient la sortie suivante :

# %% [markdown]
# ![Multiplex3.jpeg](attachment:Multiplex3.jpeg)
#
# <p style="text-align: center;">Figure n°4 : écran de l'oscilloscope </p>

# %% [markdown]
# 6. En analysant à la fois l’évolution temporelle et fréquentielle du signal d’entrée, de sortie et en vous appuyant sur le diagramme de Bode, justifier la forme du signal de sortie. Qu’a-t-on isolé ? Comment pourrait-on encore améliorer ce procédé ?

# %% [markdown]
# Réponse :

# %% [markdown]
# ### C : Caractères intégrateur et dérivateur du filtre
#
# 7. Proposer et mettre en oeuvre un protocole permettant de démontrer le caractère intégrateur (sous conditions) du filtre.

# %% [markdown]
# Réponse :

# %% [markdown]
# 8. Proposer et mettre en oeuvre un protocole permettant de démontrer le caractère dérivateur.

# %% [markdown]
# Réponse :

# %% [markdown]
# ## Annexe : amplificateur linéaire intégré
#
# L’amplificateur linéaire intégré est un composant électronique permettant, entre autres, d’amplifier la différence de potentiel $v^+-v^-$ entre les entrées $+$ et $−$.

# %% [markdown]
# ![ALI.jpeg](attachment:ALI.jpeg)
#
# <p style="text-align: center;">Figure n°5 : Amplificateur Linéaire Intégré</p>

# %% [markdown]
# En fonctionnement idéal, un ALI vérifie les conditions suivantes :
# $$i^+ = i^- = 0$$
# et
# $$V^+ = V^-$$
# en régime linéaire avec $|V_s| < V_{sat}\simeq 12$ V.
